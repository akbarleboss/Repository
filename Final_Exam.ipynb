# %%
import yfinance as yf

# data extraction
tesla_data = yf.download("TSLA", start="2022-01-01", end="2023-01-01")

# index reset
tesla_data.reset_index(inplace=True)

# data view
tesla_data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2022-01-03  382.583344  400.356659  378.679993  399.926666  399.926666
# 1 2022-01-04  396.516663  402.666656  374.350006  383.196655  383.196655
# 2 2022-01-05  382.216675  390.113342  360.336670  362.706665  362.706665
# 3 2022-01-06  359.000000  362.666656  340.166656  354.899994  354.899994
# 4 2022-01-07  360.123322  360.309998  336.666656  342.320007  342.320007
#
#       Volume
# 0  103931400
# 1  100248300
# 2   80119800
# 3   90336600
# 4   84164700

# %%
# Display the last five rows of the tesla_revenue dataframe
# data extraction
tesla_revenue = yf.download("TSLA", start="2022-01-01", end="2023-01-01")

# index reset
tesla_revenue.reset_index(inplace=True)

# data view
tesla_revenue.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#           Date        Open        High         Low       Close   Adj Close  \
# 246 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 247 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 248 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 249 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 250 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#         Volume
# 246  166989700
# 247  208643400
# 248  221070500
# 249  221923300
# 250  157777300

# %%
import yfinance as yf

# Extract stock data for GameStop (GME)
gme_data = yf.download("GME", start="2022-01-01", end="2023-01-01")

# Reset the index
gme_data.reset_index(inplace=True)

# Display the first five rows of the gme_data dataframe
gme_data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2022-01-03  37.307499  39.845001  37.302502  38.209999  38.209999   5654800
# 1 2022-01-04  38.042500  38.247501  35.762501  37.227501  37.227501   7339600
# 2 2022-01-05  37.097500  37.212502  32.287498  32.342499  32.342499  13585600
# 3 2022-01-06  33.209999  34.424999  30.285000  32.757500  32.757500  24206000
# 4 2022-01-07  39.942501  40.077499  33.125000  35.154999  35.154999  48549200

# %%
import yfinance as yf

# Extract stock data for GameStop (GME)
gme_revenue = yf.download("GME", start="2022-01-01", end="2023-01-01")

# Reset the index
gme_revenue.reset_index(inplace=True)

# Display the first five rows of the gme_data dataframe
gme_data.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#           Date       Open       High    Low      Close  Adj Close   Volume
# 246 2022-12-23  20.000000  20.629999  19.65  20.080000  20.080000  3174800
# 247 2022-12-27  19.910000  19.990000  18.00  18.200001  18.200001  4233000
# 248 2022-12-28  18.290001  18.700001  16.98  17.920000  17.920000  5672000
# 249 2022-12-29  18.120001  18.570000  17.75  18.330000  18.330000  3442800
# 250 2022-12-30  17.950001  18.580000  17.90  18.459999  18.459999  2669500

# %%
import matplotlib.pyplot as plt
def make_graph(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data['Date'], data['Close'], label='Tesla Stock Price', color='blue')
    plt.xlabel('Date')
    plt.ylabel('Stock Price (USD)')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()
tesla_data = yf.download("TSLA", start="2022-01-01", end="2023-01-01")
tesla_data.reset_index(inplace=True)
make_graph(tesla_data, 'Tesla Stock Price (2022-2023)')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
def make_graph(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data['Date'], data['Close'], label='GameStop Stock Price', color='red')
    plt.xlabel('Date')
    plt.ylabel('Stock Price (USD)')
    plt.title(title),  plt.legend(), plt.grid(True), plt.show()
     
gme_data = yf.download("GME", start="2022-01-01", end="2023-01-01")

gme_data.reset_index(inplace=True)

make_graph(gme_data, 'GameStop Stock Price (2022-2023)')
# Out:
# [*********************100%%**********************]  1 of 1 completed
